# %% [markdown]
# # Intro to Python
#
# ---
# ## 📌 Why Python?
# - Python is one of the most commonly used languages in Data Science.
# - Highly flexible and beginner-friendly.
# - Has gained immense popularity over the years due to its simplicity and community support.
#
# ### Usage trends (according to TIOBE Index):
# Python consistently ranks among the top programming languages, surpassing others like Java, C++, JavaScript, etc.
#
# ---
# ## 🧠 Key Characteristics of Python
# - **High-level language**: Close to human language, abstracting away low-level system details.
# - **General-purpose**: Used in data science, machine learning, web development, automation, and more.
# - **Cross-platform**: Compatible with Windows, macOS, and Linux.
# - **Rich ecosystem**: Thousands of libraries available (e.g., NumPy, Pandas, TensorFlow, Flask).
# - **Supports multiple paradigms**: Procedural, object-oriented, functional programming.
#
# ---
# ## ✅ Advantages
# - Simple, clean, and readable syntax.
# - Strong community and abundant resources (forums, tutorials, docs).
# - Widely adopted in academia and industry (Google, Facebook, Netflix, etc.).
#
# ---
# ## ⚠️ Downsides of Python
# - **Runtime interpreted**: Slower compared to compiled languages like C/C++.
# - **Higher energy consumption**: Less efficient in terms of CPU and memory.
# - **Not optimal for multithreading**: Due to the Global Interpreter Lock (GIL).
# - **Dependency management**: Some libraries may be poorly maintained.
#
# ---
# ## ☁️ Google Colab Overview
# - Cloud-based Jupyter-like notebook platform.
# - No need for local setup.
# - Great for collaborative projects (like Google Docs).
# - Comes with optional access to GPU/TPU (in free or paid tiers).
#
# ### Limitations
# - Sessions timeout on inactivity.
# - No persistent environment; changes reset after session ends.
# - Limited free GPU time; for intensive workloads, consider Colab Pro.
